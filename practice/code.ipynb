# %%
#pip install --upgrade seaborn

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load sample dataset
tips = sns.load_dataset("tips")

# Set a visual theme
sns.set_theme(style="darkgrid")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Save to CSV
tips.to_csv("tips_dataset.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# '/Users/dineshbosegandhi/Documents/GitHub/datascience/practice'

# %%
plt.figure(figsize=(8, 6))

# %%
#1. Scatter Plot: Total Bill vs Tip, with hue and size

sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time", size="size", palette="deep")
plt.title("Scatter Plot: Total Bill vs Tip by Time and Size")
plt.show()

# %%
# 2. Line Plot: Total Bill by Party Size, split by Sex

sns.lineplot(data=tips, x="size", y="total_bill", hue="sex", ci=None, marker="o")
plt.title("Line Plot: Total Bill by Party Size and Sex")
plt.show()

# %%
# 3. Bar Plot: Average Total Bill by Day, split by Sex

sns.barplot(data=tips, x="day", y="total_bill", hue="sex", palette="muted")
plt.title("Bar Plot: Average Total Bill by Day and Sex")
plt.show()

# %%
# 4. Box Plot: Total Bill by Day, split by Time

sns.boxplot(data=tips, x="day", y="tip", hue="smoker", palette="Set2")
plt.title("Box Plot: Tips by Day and Smoker Status")
plt.show()

# %%
## 5. Violin Plot: Total Bill by Day, split by Time

sns.violinplot(data=tips, x="day", y="total_bill", hue="time", split=True, palette="pastel")
plt.title("Violin Plot: Total Bill by Day and Time")
plt.show()

# %%
# 6. Count Plot: Orders by Day, split by Smoker

sns.countplot(data=tips, x="day", hue="smoker", palette="dark")
plt.title("Count Plot: Orders by Day and Smoker Status")
plt.show()

# %%
# 7. Regression Plot: Total Bill vs Tip with regression line

sns.regplot(data=tips, x="total_bill", y="tip", scatter_kws={"s": 50}, line_kws={"color": "red"})
plt.title("Regression Plot: Total Bill vs Tip")
plt.show()

# %%
#8. Histogram (Distribution Plot): Total Bill with KDE

sns.histplot(data=tips, x="total_bill", kde=True, bins=20, color="blue")
plt.title("Histogram: Distribution of Total Bill")
plt.show()

# %%
#9. Pair Plot: Relationships between numerical variables

sns.pairplot(tips, hue="sex", vars=["total_bill", "tip", "size"], palette="husl")
plt.suptitle("Pair Plot: Numerical Variables by Sex", y=1.02)
plt.show()

# %%
# 10. Catplot (Point Plot): Tip by Day and Sex

sns.catplot(data=tips, x="day", y="tip", hue="sex", kind="point", palette="bright")
plt.title("Catplot (Point): Tips by Day and Sex")
plt.show()

# %%
# 11. Joint Plot: Total Bill vs Tip with marginal distributions
sns.jointplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker", palette="coolwarm")
plt.suptitle("Joint Plot: Total Bill vs Tip by Smoker", y=1.02)
plt.show()

# %%
# 12. FacetGrid: Total Bill by Day, faceted by Time and Smoker
g = sns.FacetGrid(tips, col="time", row="smoker", margin_titles=True)
g.map(sns.histplot, "total_bill", bins=15)
g.fig.suptitle("FacetGrid: Total Bill by Time and Smoker", y=1.02)
plt.show()

# %%
# 13. Strip Plot: Tips by Day, colored by Sex
plt.figure(figsize=(8, 6))
sns.stripplot(data=tips, x="day", y="tip", hue="sex", palette="Set1", jitter=True)
plt.title("Strip Plot: Tips by Day and Sex")
plt.show()

# %%
# 14. KDE Plot: Total Bill density by Sex
plt.figure(figsize=(8, 6))
sns.kdeplot(data=tips, x="total_bill", hue="sex", fill=True, palette="tab10")
plt.title("KDE Plot: Total Bill Density by Sex")
plt.show()

# %% [markdown]
# #Explanation of Plots:
#
# - Scatter Plot: Shows the relationship between total_bill and tip, with time and size as additional dimensions.
# - Line Plot: Trends of total_bill across size, split by sex.
# - Bar Plot: Average total_bill by day, split by sex.
# - Box Plot: Distribution of tip by day, split by smoker.
# - Violin Plot: Distribution of total_bill by day, split by time.
# - Count Plot: Counts of orders by day, split by smoker.
# - Regression Plot: Linear fit between total_bill and tip.
# - Histogram: Distribution of total_bill with a KDE curve.
# - Pair Plot: Pairwise relationships between total_bill, tip, and size, colored by sex.
# - Catplot (Point): Point estimates of tip by day and sex.
# - Joint Plot: total_bill vs tip with marginal histograms, colored by smoker.
# - FacetGrid: total_bill histograms faceted by time and smoker.
# - Strip Plot: Individual tip points by day, colored by sex.
# - KDE Plot: Density of total_bill split by sex.

# %%
import streamlit as st
import seaborn as sns
import matplotlib.pyplot as plt

# Set Seaborn style
sns.set(style="whitegrid")

# Load the tips dataset
tips = sns.load_dataset('tips')

# Streamlit app
st.title("Comprehensive Tips Dataset Visualizations by prakash senapati")
st.write("This app displays a variety of Seaborn plots created by prakash senapati exploring the Tips dataset, which includes data on restaurant bills and tips.")

# Function to create and display a plot
def display_plot(title, plot_func):
    st.subheader(title)
    fig, ax = plt.subplots(figsize=(8, 6))
    plot_func(ax)
    st.pyplot(fig)
    plt.close(fig)  # Close the figure to free memory

# Plot definitions
def scatter_plot(ax):
    sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time", size="size", palette="deep", ax=ax)
    ax.set_title("Scatter Plot: Total Bill vs Tip by Time and Size")

def line_plot(ax):
    sns.lineplot(data=tips, x="size", y="total_bill", hue="sex", ci=None, marker="o", ax=ax)
    ax.set_title("Line Plot: Total Bill by Party Size and Sex")

def bar_plot(ax):
    sns.barplot(data=tips, x="day", y="total_bill", hue="sex", palette="muted", ax=ax)
    ax.set_title("Bar Plot: Average Total Bill by Day and Sex")

def box_plot(ax):
    sns.boxplot(data=tips, x="day", y="tip", hue="smoker", palette="Set2", ax=ax)
    ax.set_title("Box Plot: Tips by Day and Smoker Status")

def violin_plot(ax):
    sns.violinplot(data=tips, x="day", y="total_bill", hue="time", split=True, palette="pastel", ax=ax)
    ax.set_title("Violin Plot: Total Bill by Day and Time")

def count_plot(ax):
    sns.countplot(data=tips, x="day", hue="smoker", palette="dark", ax=ax)
    ax.set_title("Count Plot: Orders by Day and Smoker Status")

def reg_plot(ax):
    sns.regplot(data=tips, x="total_bill", y="tip", scatter_kws={"s": 50}, line_kws={"color": "red"}, ax=ax)
    ax.set_title("Regression Plot: Total Bill vs Tip")

def hist_plot(ax):
    sns.histplot(data=tips, x="total_bill", kde=True, bins=20, color="blue", ax=ax)
    ax.set_title("Histogram: Distribution of Total Bill")

def strip_plot(ax):
    sns.stripplot(data=tips, x="day", y="tip", hue="sex", palette="Set1", jitter=True, ax=ax)
    ax.set_title("Strip Plot: Tips by Day and Sex")

def swarm_plot(ax):
    sns.swarmplot(data=tips, x="day", y="tip", hue="smoker", palette="Set3", ax=ax)
    ax.set_title("Swarm Plot: Tips by Day and Smoker Status")

def kde_plot(ax):
    sns.kdeplot(data=tips, x="total_bill", hue="sex", fill=True, palette="tab10", ax=ax)
    ax.set_title("KDE Plot: Total Bill Density by Sex")

# Special cases that need custom handling
st.subheader("Pair Plot: Numerical Variables by Sex")
pair_fig = sns.pairplot(tips, hue="sex", vars=["total_bill", "tip", "size"], palette="husl")
pair_fig.fig.suptitle("Pair Plot: Numerical Variables by Sex", y=1.02)
st.pyplot(pair_fig.fig)
plt.close(pair_fig.fig)

st.subheader("Joint Plot: Total Bill vs Tip by Smoker")
joint_fig = sns.jointplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker", palette="coolwarm")
joint_fig.fig.suptitle("Joint Plot: Total Bill vs Tip by Smoker", y=1.02)
st.pyplot(joint_fig.fig)
plt.close(joint_fig.fig)

st.subheader("FacetGrid: Total Bill by Time and Smoker")
g = sns.FacetGrid(tips, col="time", row="smoker", margin_titles=True)
g.map(sns.histplot, "total_bill", bins=15)
g.fig.suptitle("FacetGrid: Total Bill by Time and Smoker", y=1.02)
st.pyplot(g.fig)
plt.close(g.fig)

st.subheader("Catplot (Point): Tips by Day and Sex")
cat_fig = sns.catplot(data=tips, x="day", y="tip", hue="sex", kind="point", palette="bright")
cat_fig.fig.suptitle("Catplot (Point): Tips by Day and Sex", y=1.02)
st.pyplot(cat_fig.fig)
plt.close(cat_fig.fig)

# Display all standard plots
display_plot("Scatter Plot", scatter_plot)
display_plot("Line Plot", line_plot)
display_plot("Bar Plot", bar_plot)
display_plot("Box Plot", box_plot)
display_plot("Violin Plot", violin_plot)
display_plot("Count Plot", count_plot)
display_plot("Regression Plot", reg_plot)
display_plot("Histogram", hist_plot)
display_plot("Strip Plot", strip_plot)
display_plot("Swarm Plot", swarm_plot)
display_plot("KDE Plot", kde_plot)

st.write("All Seaborn plots for the Tips dataset have been generated!")
# Out:
# 2026-02-14 15:35:44.831 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:45.085
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/anaconda3/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-02-14 15:35:45.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:45.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:45.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:45.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:45.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:46.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:46.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:46.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:46.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:46.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:47.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# /var/folders/6z/dl2_c4v120j8_v48x2txh5sm0000gn/T/ipykernel_98464/355373577.py:29: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=tips, x="size", y="total_bill", hue="sex", ci=None, marker="o", ax=ax)
# 2026-02-14 15:35:48.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:48.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:49.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:50.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-14 15:35:51.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
